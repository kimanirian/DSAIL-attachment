# %% [markdown]
# ## Coffee data analysis

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Sorted_coffee.csv")
df
# Out:
#      Year      Month  Volume Coffee (Tonnes)  Value Coffee (Kshs. Millions)  \
# 0    1998   December                 3565.01                         574.54
# 1    1998   November                 3958.47                         578.74
# 2    1998    October                 4158.57                         584.32
# 3    1998  September                 3243.70                         536.21
# 4    1998     August                 2759.82                         500.47
# ..    ...        ...                     ...                            ...
# 295  2023   February                 4060.85                        2684.98
# 296  2023      March                 5750.19                        4099.69
# 297  2023      April                 5667.74                        4111.12
# 298  2023        May                 6447.50                        4839.14
# 299  2023       June                 7279.04                        5186.01
#
# ...

# %%
df.dtypes
# Out:
# Year                                        int64
# Month                                      object
# Volume Coffee (Tonnes)                    float64
# Value Coffee (Kshs. Millions)             float64
# Average Coffee (Kshs. per Tonne)          float64
# Volume Tea  (Tonnes)                      float64
# Value Tea (Kshs. Millions)                float64
# Average Tea (Kshs. per Tonne)             float64
# Volume Horticulture  (Tonnes)             float64
# Value Horticulture (Kshs. Millions)       float64
# Average Horticulture (Kshs. per Tonne)    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Volume Coffee (Tonnes)',
#        'Value Coffee (Kshs. Millions)', 'Average Coffee (Kshs. per Tonne)',
#        'Volume Tea  (Tonnes)', 'Value Tea (Kshs. Millions)',
#        'Average Tea (Kshs. per Tonne)', 'Volume Horticulture  (Tonnes)',
#        'Value Horticulture (Kshs. Millions)',
#        'Average Horticulture (Kshs. per Tonne)'],
#       dtype='object')

# %%
#visualisation of cofee volume
import seaborn as sns
df1=pd.DataFrame(df)
fig = plt.subplots(figsize=(20, 5))
sns.lineplot(x='Year', y='Volume Coffee (Tonnes)', data=df1)
# Out:
# <Axes: xlabel='Year', ylabel='Volume Coffee (Tonnes)'>

# %%
df.shape
# Out:
# (300, 11)

# %%
df.describe()
# Out:
#               Year  Volume Coffee (Tonnes)  Value Coffee (Kshs. Millions)  \
# count   300.000000              300.000000                     300.000000
# mean   2010.583333             4329.205667                    1436.848267
# std       7.240013             1507.366451                     896.552392
# min    1998.000000             1461.380000                     130.210000
# 25%    2004.000000             3277.652500                     737.167500
# 50%    2011.000000             4061.730000                    1287.345000
# 75%    2017.000000             4996.727500                    1848.222500
# max    2023.000000            11856.510000                    5186.010000
#
#        Average Coffee (Kshs. per Tonne)  Volume Tea  (Tonnes)  \
# count                        300.000000            300.000000
# mean                      347105.838900          32744.829100
# std                       194048.346809           9579.182358
# ...

# %%
#ploting the visualization for coffee volume in tonnes
df['Volume Coffee (Tonnes)'].plot()
# Out:
# <Axes: >

# %%
##Visualizing the calue of Kenyan coffee in Kenyan shillings
df1=pd.DataFrame(df)
fig = plt.subplots(figsize=(20, 5))
sns.lineplot(x='Year', y='Value Coffee (Kshs. Millions)', data=df1)
# Out:
# <Axes: xlabel='Year', ylabel='Value Coffee (Kshs. Millions)'>

# %%
#plotting the Visualization for the prices
df['Value Coffee (Kshs. Millions)'].plot()
# Out:
# <Axes: >

# %%
#grouping the cofee production in years
grup_df=df.groupby('Year')
grup_df.describe()
# Out:
#      Volume Coffee (Tonnes)                                                \
#                       count         mean          std      min        25%
# Year
# 1998                    5.0  3537.114000   560.090252  2759.82  3243.7000
# 1999                   12.0  5952.096667  2792.541701  1461.38  4416.4775
# 2000                   12.0  7248.518333  1868.562778  3956.92  5972.1450
# 2001                   12.0  5089.918333  1372.336345  2195.50  4081.7725
# 2002                   12.0  4123.275833  1231.708483  2433.27  3510.7400
# 2003                   12.0  4887.538333  1076.461181  3028.60  4478.4525
# 2004                   12.0  4134.520000  1155.243786  2483.61  3263.8950
# 2005                   12.0  4245.942500  1533.026905  2055.99  3540.2100
# 2006                   12.0  4153.776667  1519.243301  2369.82  3061.7650
# 2007                   12.0  4948.481667  1715.185099  2462.35  3717.6875
# 2008                   12.0  3677.843333   763.830180  2781.48  3111.3500
# ...

# %%
fig = plt.subplots(figsize=(20, 5))
sns.lineplot(x='Year', y='Average Coffee (Kshs. per Tonne)', data=df1)
# Out:
# <Axes: xlabel='Year', ylabel='Average Coffee (Kshs. per Tonne)'>

# %% [markdown]
# ## Findings
# From the data its evident that the volume of the coffee being produced in Kenya has been steadily increasing over time
#
# Also it is evident that as the volume of the coffee keeps decreasing the value have kept on rising due to the demand and the the supply effect of the same
